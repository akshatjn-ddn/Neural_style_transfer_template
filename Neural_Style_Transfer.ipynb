# %%
import tensorflow_hub as hub 
import tensorflow as tf
import matplotlib.pyplot as plt 
import cv2
import numpy as np

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %% [markdown]
# ## Preprocess Images

# %%
def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
content_image = load_img('0.jpg')
style_image = load_img('monet.jpeg')

# %%
plt.imshow(np.squeeze(content_image))
plt.show()

# %%
plt.imshow(np.squeeze(style_image))
plt.show()

# %% [markdown]
# ## Stylize Image

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
def stylize_img(content_image, style_image):
    stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
    plt.imshow(np.squeeze(stylized_image))
    plt.show()
    return stylized_image

# %%
content_image = load_img('0.jpg')
style_image = load_img('park.jpeg')
stylized_image = stylize_img(content_image=content_image, style_image = style_image)

# %%
content_image = load_img('0.jpg')
style_image = load_img('klimt.jpg')
stylized_image = stylize_img(content_image=content_image, style_image = style_image)

# %%
content_image = load_img('0.jpg')
style_image = load_img('frida.jpg')
stylized_image = stylize_img(content_image=content_image, style_image = style_image)
